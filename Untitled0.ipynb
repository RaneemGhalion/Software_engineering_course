# %%
# !echo "# Software_engineering_course" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/RaneemGhalion/Software_engineering_course.git
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@ced65d84a15d.(none)')
# error: src refspec main does not match any
# ...

# %%
# !git config --global user.email "ranem.a.ghalion@gmail.com"
# !git config --global user.name "Raneem Ghalion"

# %%
# !ls
# Out:
# README.md  sample_data

# %%
# %cd ..
# Out:
# /

# %%
# !ls
# Out:
# bin	 cuda-keyring_1.0-1_all.deb  etc   lib32   media		     opt   run	 sys	usr
# boot	 datalab		     home  lib64   mnt			     proc  sbin  tmp	var
# content  dev			     lib   libx32  NGC-DL-CONTAINER-LICENSE  root  srv	 tools

# %%
# %cd Software_engineering_course
# Out:
# /content/drive/MyDrive/Software_engineering_course

# %%
# !ls
# Out:
# code  README.md  Untitled0.ipynb

# %%
# !git pull
# Out:
# ["Your configuration specifies to merge with the ref 'refs/heads/main'",
#  'from the remote, but no such ref was fetched.']

# %%
# !git fetch origin

# %%
# !git branch -r

# %%
# !git branch --set-upstream-to=origin/main
# Out:
# error: the requested upstream branch 'origin/main' does not exist
# hint:
# hint: If you are planning on basing your work on an upstream
# hint: branch that already exists at the remote, you may need to
# hint: run "git fetch" to retrieve it.
# hint:
# hint: If you are planning to push out a new local branch that
# hint: will track its remote counterpart, you may want to use
# hint: "git push -u" to set the upstream config as you push.

# %%
# !git clone https://github.com/RaneemGhalion/Software_engineering_course.git
# Out:
# Cloning into 'Software_engineering_course'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !ls
# Out:
# code  README.md  Software_engineering_course  Untitled0.ipynb

# %%
# %cd Software_engineering_course
# Out:
# /content/drive/MyDrive/Software_engineering_course/Software_engineering_course

# %%
# !ls
# Out:
# README.md

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !touch Lect1.ipynb

# %%
# !ls
# Out:
# code  Lect1.ipynb  README.md

# %%
# !git add .

# %%
# !git commit -m'First commit'
# Out:
# [main e92fd1e] First commit
#  8 files changed, 4431 insertions(+)
#  create mode 100644 Lect1.ipynb
#  create mode 100644 code/Default Values - Beware.ipynb
#  create mode 100644 code/Extended Unpacking.ipynb
#  create mode 100644 code/Keyword Arguments.ipynb
#  create mode 100644 code/Positional Arguments.ipynb
#  create mode 100644 code/Putting it all Together.ipynb
#  create mode 100644 code/Unpacking Iterables.ipynb
#  create mode 100644 code/star-args.ipynb

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !ssh-keygen -t rsa -b 4096 -C "ranem.a.ghalion@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:iF/XGaxETfKilN3p4CWXN2VkCceulC1B4K8VbRpbusE ranem.a.ghalion@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |          o++ooo*|
# |         +.=.+o* |
# |        o *.XoB+ |
# |     . o + XoBO+ |
# |    . . S + =Eo  |
# |     . . .  o.o  |
# |      .    . .   |
# |                 |
# |                 |
# +----[SHA256]-----+

# %%
# !git remote set-url origin https://github.com/RaneemGhalion/Software_engineering_course.git

# %%
# !git commit -m'first commit -m'
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --get remote.origin.url
# Out:
# https://github.com/RaneemGhalion/Software_engineering_course.git

# %%
# !git credential-cache exit

# %%
# !git config --global credential.helper store

# %%
# !sudo apt-key adv --keyserver keyserver.ubuntu.com --recv-key C99B11DEB97541F0
# !sudo apt-add-repository https://cli.github.com/packages
# !sudo apt update
# !sudo apt install gh
# Out:
# ...
# Executing: /tmp/apt-key-gpghome.WtYGfNH6Tu/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-key C99B11DEB97541F0
# gpg: key C99B11DEB97541F0: public key "Nate Smith <vilmibm@github.com>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Repository: 'deb https://cli.github.com/packages jammy main'
# Description:
# Archive for codename: jammy components: main
# More info: https://cli.github.com/packages
# Adding repository.
# Press [ENTER] to continue or Ctrl-c to cancel.
# Adding deb entry to /etc/apt/sources.list.d/archive_uri-https_cli_github_com_packages-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/archive_uri-https_cli_github_com_packages-jammy.list
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# ...

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !gh repo clone RaneemGhalion/Software_engineering_course
# Out:
# Welcome to GitHub CLI!
#
# To authenticate, please run `gh auth login`.

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://github.com/RaneemGhalion/Software_engineering_course.git (fetch)
# origin	https://github.com/RaneemGhalion/Software_engineering_course.git (push)

# %%
# !git config --global credential.helper store

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global credential.helper store
# !git clone https://RaneemGhalion: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@github.com/RaneemGhalion/Software_engineering_course.git
# Out:
# Cloning into 'Software_engineering_course'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !git push origin main
# Out:
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (11/11), 13.16 KiB | 280.00 KiB/s, done.
# Total 11 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), done.
# To https://github.com/RaneemGhalion/Software_engineering_course.git
#    123b117..e92fd1e  main -> main

# %%
# !git add .

# %%
# !git commit -m'folder deleted'
# Out:
# [main 0287a4d] folder deleted
#  7 files changed, 0 insertions(+), 0 deletions(-)
#  rename {code => Lecture1_code}/Default Values - Beware.ipynb (100%)
#  rename {code => Lecture1_code}/Extended Unpacking.ipynb (100%)
#  rename {code => Lecture1_code}/Keyword Arguments.ipynb (100%)
#  rename {code => Lecture1_code}/Positional Arguments.ipynb (100%)
#  rename {code => Lecture1_code}/Putting it all Together.ipynb (100%)
#  rename {code => Lecture1_code}/Unpacking Iterables.ipynb (100%)
#  rename {code => Lecture1_code}/star-args.ipynb (100%)

# %%
# !git push origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 312 bytes | 34.00 KiB/s, done.
# Total 2 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/RaneemGhalion/Software_engineering_course.git
#    e92fd1e..0287a4d  main -> main
